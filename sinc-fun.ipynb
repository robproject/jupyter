# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 4, 100)

# %%
vals = 500 * np.sinc(50*x)

# %%
plt.plot(x, vals)
plt.show()

# %%
print(np.sin(np.pi *3)/(np.pi * 3))
print(np.sinc(3))
# Out:
# 3.8981718325193755e-17
# 3.8981718325193755e-17
